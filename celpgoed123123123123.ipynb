# %%
#import sklearn.metrics.pairwise as pw
import re
#import spacy
import pandas as pd
import numpy as np
#import sklearn
import os
import json
import random

# %%
city = 'ambridge'

# %%
with open(f"data/{city}/business.json", "r") as f:
    data = []
    for line in f:
                data.append(json.loads(line))
with open(f"data/{city}/user.json", "r") as f:
    udata = []
    for line in f:
                udata.append(json.loads(line))
with open(f"data/{city}/review.json", "r") as f:
    rdata = []
    for line in f:
                rdata.append(json.loads(line))

# %%
def create_similarity_matrix_categories(matrix):
    """Create a  """
    npu = matrix.values
    m1 = npu @ npu.T
    diag = np.diag(m1)
    m2 = m1 / diag
    m3 = np.minimum(m2, m2.T)
    return pd.DataFrame(m3, index = matrix.index, columns = matrix.index)

# %%
def mse(predicted_ratings):
    """Computes the mean square error between actual ratings and predicted ratings
    
    Arguments:
    predicted_ratings -- a dataFrame containing the columns rating and predicted rating
    """
    diff = predicted_ratings['stars'] - predicted_ratings['predicted stars']
    return (diff**2).mean()

# %%
def predict_ratings(similarity, utility, to_predict):
    """Predicts the predicted rating for the input test data.
    
    Arguments:
    similarity -- a dataFrame that describes the similarity between items
    utility    -- a dataFrame that contains a rating for each user (columns) and each movie (rows). 
                  If a user did not rate an item the value np.nan is assumed. 
    to_predict -- A dataFrame containing at least the columns movieId and userId for which to do the predictions
    """
    # copy input (don't overwrite)
    ratings_test_c = to_predict.copy()
    # apply prediction to each row
    ratings_test_c['predicted stars'] = to_predict.apply(lambda row: predict_ids(similarity, utility, row['user_id'], row['business_id']), axis=1)
    return ratings_test_c

### Helper functions for predict_ratings_item_based ###

def predict_ids(similarity, utility, userId, itemId):
    # select right series from matrices and compute
    if userId in utility.columns and itemId in similarity.index:
        return predict_vectors(utility.loc[:,userId], similarity[itemId])
    return 0

def predict_vectors(user_ratings, similarities):
    # select only movies actually rated by user
    relevant_ratings = user_ratings.dropna()
    
    # select corresponding similairties
    similarities_s = similarities[relevant_ratings.index]
    
    # select neighborhood
    similarities_s = similarities_s[similarities_s > 0.0]
    relevant_ratings = relevant_ratings[similarities_s.index]
    
    # if there's nothing left return a prediction of 0
    norm = similarities_s.sum()
    if(norm == 0):
        return 0
    
    # compute a weighted average (i.e. neighborhood is all) 
    return np.dot(relevant_ratings, similarities_s)/norm

# %%
# %%time
# maak utility matrix
utility_matrix = pd.DataFrame(index = [i['business_id'] for i in data], columns = [i['user_id'] for i in udata])

# utility_matrix invullen
rvs = [[review['business_id'], review['user_id'], review['stars']] for review in rdata]
for review in rvs:
    utility_matrix.loc[review[0], review[1]] = review[2]
utility_matrix.index.name = 'business_id'
utility_matrix.columns.name = 'user_id'

# maak similarity_matrix
tlist = [[data[i]['business_id'], data[i]['categories'].split(', ')[x]] for i in range(len(data))  if data[i]['categories'] != None for x in range(len(data[i]['categories'].split(', ')))]
catpd = pd.DataFrame(data=tlist, columns=['business_id', 'categories'])
aye = catpd.pivot_table(index = 'business_id', columns = 'categories', aggfunc = 'size', fill_value=0)
sim_matrix = create_similarity_matrix_categories(aye)

# DataFrame maken voor predict_ratings()
strtst = pd.DataFrame(rvs, columns = ['business_id', 'user_id', 'stars'])

# predict ratings
tsting = predict_ratings(sim_matrix, utility_matrix,  strtst[['user_id', 'business_id', 'stars']])
# Out:
# Wall time: 434 ms

# %%
mse(tsting)
# Out:
# 0.09087292219400735

# %%
display(sim_matrix.head()), display(utility_matrix.head()), display(tsting.head())
# Out:
# business_id             -InU2nAbC9AuS-Um2Cowgw  0EyRe-VkW8gYxxZ7NCQXeQ  \
# business_id
# -InU2nAbC9AuS-Um2Cowgw                    1.00                    0.50
# 0EyRe-VkW8gYxxZ7NCQXeQ                    0.50                    1.00
# 2_7lYF6P2cYKnSiPhhVyPQ                    0.25                    0.25
# 3gL18eXylqutlzqb6TmB0w                    0.00                    0.00
# 4mpSNvmyG89Uqy2ahP4JMQ                    0.25                    0.25
#
# business_id             2_7lYF6P2cYKnSiPhhVyPQ  3gL18eXylqutlzqb6TmB0w  \
# business_id
# -InU2nAbC9AuS-Um2Cowgw                    0.25                     0.0
# 0EyRe-VkW8gYxxZ7NCQXeQ                    0.25                     0.0
# 2_7lYF6P2cYKnSiPhhVyPQ                    1.00                     0.0
# 3gL18eXylqutlzqb6TmB0w                    0.00                     1.0
# 4mpSNvmyG89Uqy2ahP4JMQ                    0.25                     0.0
#
# business_id             4mpSNvmyG89Uqy2ahP4JMQ  729grSa1Wsn-hfv7D5uOxg  \
# business_id
# -InU2nAbC9AuS-Um2Cowgw                    0.25                0.250000
# 0EyRe-VkW8gYxxZ7NCQXeQ                    0.25                0.666667
# 2_7lYF6P2cYKnSiPhhVyPQ                    0.25                0.250000
# 3gL18eXylqutlzqb6TmB0w                    0.00                0.000000
# 4mpSNvmyG89Uqy2ahP4JMQ                    1.00                0.250000
#
# business_id             7xRbOtZUuw7DxOWrHeaanw  EOmRHPvzR88a5R2j2uD0cQ  \
# business_id
# -InU2nAbC9AuS-Um2Cowgw                0.250000                     0.0
# 0EyRe-VkW8gYxxZ7NCQXeQ                0.333333                     0.0
# 2_7lYF6P2cYKnSiPhhVyPQ                0.250000                     0.0
# 3gL18eXylqutlzqb6TmB0w                0.000000                     0.0
# 4mpSNvmyG89Uqy2ahP4JMQ                0.250000                     0.0
#
# business_id             EZ9zSk4ld27LwgfANoF4VA  Eu_zPTrNVAXkpdSxf7CJ2w  \
# business_id
# -InU2nAbC9AuS-Um2Cowgw                     0.0                0.250000
# 0EyRe-VkW8gYxxZ7NCQXeQ                     0.0                0.333333
# 2_7lYF6P2cYKnSiPhhVyPQ                     0.0                0.500000
# 3gL18eXylqutlzqb6TmB0w                     0.0                0.000000
# 4mpSNvmyG89Uqy2ahP4JMQ                     0.0                0.250000
#
# business_id                      ...            lawYwEXAE-Sq2nf6co7aBg  \
# business_id                      ...
# -InU2nAbC9AuS-Um2Cowgw           ...                               0.0
# 0EyRe-VkW8gYxxZ7NCQXeQ           ...                               0.0
# 2_7lYF6P2cYKnSiPhhVyPQ           ...                               0.5
# 3gL18eXylqutlzqb6TmB0w           ...                               0.0
# 4mpSNvmyG89Uqy2ahP4JMQ           ...                               0.0
#
# business_id             muFJIZKZwbAfy_pEFKF_pw  pcbVl6ZHDOJHsnetY0rJEQ  \
# business_id
# -InU2nAbC9AuS-Um2Cowgw                0.250000                     0.0
# 0EyRe-VkW8gYxxZ7NCQXeQ                0.666667                     0.0
# 2_7lYF6P2cYKnSiPhhVyPQ                0.250000                     0.0
# 3gL18eXylqutlzqb6TmB0w                0.000000                     0.0
# 4mpSNvmyG89Uqy2ahP4JMQ                0.250000                     0.0
#
# business_id             rdHO0LkiNe6s3716hPuQXQ  tTDxa8OzmxUkpVifQ-cEWw  \
# business_id
# -InU2nAbC9AuS-Um2Cowgw                    0.25                0.250000
# 0EyRe-VkW8gYxxZ7NCQXeQ                    0.25                0.333333
# 2_7lYF6P2cYKnSiPhhVyPQ                    0.75                0.250000
# 3gL18eXylqutlzqb6TmB0w                    0.00                0.000000
# 4mpSNvmyG89Uqy2ahP4JMQ                    0.25                0.250000
#
# business_id             t_EiW3FlMnFTHyoeVU79xg  xM8dVGLkYaL94EuAIkjMEA  \
# business_id
# -InU2nAbC9AuS-Um2Cowgw                0.333333                     0.0
# 0EyRe-VkW8gYxxZ7NCQXeQ                0.166667                     0.0
# 2_7lYF6P2cYKnSiPhhVyPQ                0.666667                     0.0
# 3gL18eXylqutlzqb6TmB0w                0.000000                     0.0
# 4mpSNvmyG89Uqy2ahP4JMQ                0.166667                     0.0
#
# business_id             y3IVqEFHmrkgVKj2x1Ci4w  yyGzYDh0Qa2o8vUGMEjDRA  \
# business_id
# -InU2nAbC9AuS-Um2Cowgw                     0.0                     0.0
# 0EyRe-VkW8gYxxZ7NCQXeQ                     0.0                     0.0
# 2_7lYF6P2cYKnSiPhhVyPQ                     0.0                     0.0
# 3gL18eXylqutlzqb6TmB0w                     0.0                     0.0
# 4mpSNvmyG89Uqy2ahP4JMQ                     0.0                     0.0
#
# business_id             zBeUDwWx73QTZ34A1l0adQ
# business_id
# -InU2nAbC9AuS-Um2Cowgw                0.250000
# 0EyRe-VkW8gYxxZ7NCQXeQ                0.666667
# 2_7lYF6P2cYKnSiPhhVyPQ                0.250000
# 3gL18eXylqutlzqb6TmB0w                0.000000
# 4mpSNvmyG89Uqy2ahP4JMQ                0.250000
#
# [5 rows x 36 columns]
# user_id                3FjdHwnoz-vfw6hBBtckqg rCWrxuRC8_pfagpchtHp6A  \
# business_id
# dJ0R-XT78LUQeNHQkD-G9g                    NaN                    NaN
# 3gL18eXylqutlzqb6TmB0w                    NaN                    NaN
# Q_0eGl-aElqHKukHvmLdwA                    NaN                    NaN
# Eu_zPTrNVAXkpdSxf7CJ2w                    NaN                    NaN
# Yjf0i2J9q52dYIT8UVGT3g                    NaN                    NaN
#
# user_id                9YIEYRTM1-esrPtfTVU4LA _pLmakEC1U8UPpxCUk2ZAg  \
# business_id
# dJ0R-XT78LUQeNHQkD-G9g                    NaN                    NaN
# 3gL18eXylqutlzqb6TmB0w                    NaN                    NaN
# Q_0eGl-aElqHKukHvmLdwA                    NaN                    NaN
# Eu_zPTrNVAXkpdSxf7CJ2w                    NaN                    NaN
# Yjf0i2J9q52dYIT8UVGT3g                    NaN                    NaN
#
# user_id                ZnIaEvJwrxlBUjimIpx2Qw 135DbbQnr3BEkQbBzZ9T1A  \
# business_id
# dJ0R-XT78LUQeNHQkD-G9g                    NaN                    NaN
# 3gL18eXylqutlzqb6TmB0w                    NaN                    NaN
# Q_0eGl-aElqHKukHvmLdwA                    NaN                      4
# Eu_zPTrNVAXkpdSxf7CJ2w                    NaN                    NaN
# Yjf0i2J9q52dYIT8UVGT3g                    NaN                    NaN
#
# user_id                QGgWWhEi5R4SLAKN-xwtNQ H5d_nFqzwrREE-YduK2ABg  \
# business_id
# dJ0R-XT78LUQeNHQkD-G9g                    NaN                    NaN
# 3gL18eXylqutlzqb6TmB0w                    NaN                    NaN
# Q_0eGl-aElqHKukHvmLdwA                    NaN                    NaN
# Eu_zPTrNVAXkpdSxf7CJ2w                    NaN                    NaN
# Yjf0i2J9q52dYIT8UVGT3g                    NaN                    NaN
#
# user_id                9p_vj2TD8G4kYsHT48z05g 8AwcaBJjiMpQ__FPxktwwQ  \
# business_id
# dJ0R-XT78LUQeNHQkD-G9g                    NaN                    NaN
# 3gL18eXylqutlzqb6TmB0w                    NaN                    NaN
# Q_0eGl-aElqHKukHvmLdwA                    NaN                    NaN
# Eu_zPTrNVAXkpdSxf7CJ2w                    NaN                    NaN
# Yjf0i2J9q52dYIT8UVGT3g                      5                    NaN
#
# user_id                         ...           NvJkV0wW-99rtSMflkkBtw  \
# business_id                     ...
# dJ0R-XT78LUQeNHQkD-G9g          ...                              NaN
# 3gL18eXylqutlzqb6TmB0w          ...                              NaN
# Q_0eGl-aElqHKukHvmLdwA          ...                              NaN
# Eu_zPTrNVAXkpdSxf7CJ2w          ...                              NaN
# Yjf0i2J9q52dYIT8UVGT3g          ...                              NaN
#
# user_id                Jnnzne2sDt1WLB74WfJNvg IE8-TRdT-Osv8w9fiHDZhQ  \
# business_id
# dJ0R-XT78LUQeNHQkD-G9g                    NaN                    NaN
# 3gL18eXylqutlzqb6TmB0w                    NaN                    NaN
# Q_0eGl-aElqHKukHvmLdwA                    NaN                    NaN
# Eu_zPTrNVAXkpdSxf7CJ2w                    NaN                    NaN
# Yjf0i2J9q52dYIT8UVGT3g                    NaN                    NaN
#
# user_id                SW_GcV2C7--_VpKNeL3mhA OrbH-f7wtNJk0O6wXkvqoA  \
# business_id
# dJ0R-XT78LUQeNHQkD-G9g                    NaN                    NaN
# 3gL18eXylqutlzqb6TmB0w                    NaN                    NaN
# Q_0eGl-aElqHKukHvmLdwA                    NaN                    NaN
# Eu_zPTrNVAXkpdSxf7CJ2w                    NaN                    NaN
# Yjf0i2J9q52dYIT8UVGT3g                    NaN                    NaN
#
# user_id                lL9Sppyk-mzNGJ5Uloz5-g fM8rythOmJGL-IRsiYdZqg  \
# business_id
# dJ0R-XT78LUQeNHQkD-G9g                    NaN                    NaN
# 3gL18eXylqutlzqb6TmB0w                    NaN                    NaN
# Q_0eGl-aElqHKukHvmLdwA                    NaN                    NaN
# Eu_zPTrNVAXkpdSxf7CJ2w                    NaN                    NaN
# Yjf0i2J9q52dYIT8UVGT3g                    NaN                    NaN
#
# user_id                IjiXC9ekXkP1I9kdLWogEw 01vXmAJKQ41PVi2wgYDiPA  \
# business_id
# dJ0R-XT78LUQeNHQkD-G9g                    NaN                    NaN
# 3gL18eXylqutlzqb6TmB0w                    NaN                    NaN
# Q_0eGl-aElqHKukHvmLdwA                    NaN                    NaN
# Eu_zPTrNVAXkpdSxf7CJ2w                    NaN                    NaN
# Yjf0i2J9q52dYIT8UVGT3g                    NaN                    NaN
#
# user_id                391zaCfgqkE_4WM3Up-z9Q
# business_id
# dJ0R-XT78LUQeNHQkD-G9g                    NaN
# 3gL18eXylqutlzqb6TmB0w                    NaN
# Q_0eGl-aElqHKukHvmLdwA                    NaN
# Eu_zPTrNVAXkpdSxf7CJ2w                    NaN
# Yjf0i2J9q52dYIT8UVGT3g                    NaN
#
# [5 rows x 281 columns]
#                   user_id             business_id  stars  predicted stars
# 0  hXydWH25S92HjI5hmWRSyA  dJ0R-XT78LUQeNHQkD-G9g    5.0              5.0
# 1  vo6vLeHoPl_h-Vt-YHs9_A  Q_0eGl-aElqHKukHvmLdwA    1.0              1.0
# 2  i1qyYL4fpAel8Ljt4WaZ3g  Q_0eGl-aElqHKukHvmLdwA    1.0              1.0
# 3  dUOg3fS3RTYDZUpu0CqqiA  729grSa1Wsn-hfv7D5uOxg    5.0              5.0
# 4  k2Bsnh6CV0HFX8RgGR1p9A  Q_0eGl-aElqHKukHvmLdwA    5.0              5.0
# (None, None, None)

# %%
'2lcK3d4K7FU6O8wXdWzOmA' in [data[i]['business_id'] for i in range(len(data)-1)]
# Out:
# False

# %%
tsting[tsting['stars'] != tsting['predicted stars']]
# Out:
#                     user_id             business_id  stars  predicted stars
# 15   v2hPERrqGGxsfmT293q4mA  Q_0eGl-aElqHKukHvmLdwA    5.0         4.840000
# 18   v2hPERrqGGxsfmT293q4mA  729grSa1Wsn-hfv7D5uOxg    5.0         4.860724
# 20   wFFLWorAWh3hpxVLQP8YWw  729grSa1Wsn-hfv7D5uOxg    5.0         4.714286
# 21   21D8GYYY-NptvXhBb9x08Q  729grSa1Wsn-hfv7D5uOxg    5.0         4.879397
# 22   21D8GYYY-NptvXhBb9x08Q  Q_0eGl-aElqHKukHvmLdwA    4.0         4.344262
# 25   LIHlbBXL5LsOyNpQVAU3lg  729grSa1Wsn-hfv7D5uOxg    5.0         4.571429
# 26   1gJw6DxTrf0Zmp9gDgYlrQ  Eu_zPTrNVAXkpdSxf7CJ2w    5.0         4.647059
# 28   LIHlbBXL5LsOyNpQVAU3lg  Eu_zPTrNVAXkpdSxf7CJ2w    5.0         4.800000
# 34   W40B1zLVNT8dnNZQt90mpw  729grSa1Wsn-hfv7D5uOxg    4.0         3.973684
# 38   Y8AacNK1oloBnkTQ3CLlEA  Eu_zPTrNVAXkpdSxf7CJ2w    4.0         4.320000
# 42   kiWPm6uCidjGbsolfqEkvg  Eu_zPTrNVAXkpdSxf7CJ2w    4.0         4.375000
# 45   Y8AacNK1oloBnkTQ3CLlEA  729grSa1Wsn-hfv7D5uOxg    5.0         4.640000
# 48   RLRYmD7XdbQPgXhlFI_Y7A  Eu_zPTrNVAXkpdSxf7CJ2w    3.0         2.863636
# 52   v2hPERrqGGxsfmT293q4mA  Q_0eGl-aElqHKukHvmLdwA    5.0         4.840000
# 55   vBXdvjjd_bD1-u4NUfR9lA  729grSa1Wsn-hfv7D5uOxg    5.0         4.846154
# 57   W40B1zLVNT8dnNZQt90mpw  Q_0eGl-aElqHKukHvmLdwA    4.0         4.090909
# 58   21D8GYYY-NptvXhBb9x08Q  Eu_zPTrNVAXkpdSxf7CJ2w    5.0         4.887850
# 60   m2uTGkOKcXqQJSmvsYvtMg  729grSa1Wsn-hfv7D5uOxg    5.0         4.324324
# 71   7M2P-xdlDSILMJDZVwVQ9A  Q_0eGl-aElqHKukHvmLdwA    1.0         1.500000
# 72   He5cTI8sBgNDKVA5yhEA8Q  Eu_zPTrNVAXkpdSxf7CJ2w    1.0         1.800000
# 80   rk3wVTj-FQZHT7RhqyPChg  729grSa1Wsn-hfv7D5uOxg    4.0         4.111111
# 86   AJ6oDR8G5eVbOLMvlZpKeQ  rdHO0LkiNe6s3716hPuQXQ    2.0         2.769231
# 106  W40B1zLVNT8dnNZQt90mpw  2_7lYF6P2cYKnSiPhhVyPQ    3.0         3.578947
# 109  Y8AacNK1oloBnkTQ3CLlEA  7xRbOtZUuw7DxOWrHeaanw    5.0         4.640000
# 114  W40B1zLVNT8dnNZQt90mpw  RdEb3U0CDIXElVJe3w5n6g    5.0         4.333333
# 118  kiWPm6uCidjGbsolfqEkvg  RdEb3U0CDIXElVJe3w5n6g    5.0         4.783251
# 120  Y8AacNK1oloBnkTQ3CLlEA  4mpSNvmyG89Uqy2ahP4JMQ    4.0         4.260870
# 123  8lCl40obN7k8v-wc4dAaiA  4mpSNvmyG89Uqy2ahP4JMQ    1.0         1.666667
# 126  VmRRY6ecwc1UqDwIfwwfnQ  4mpSNvmyG89Uqy2ahP4JMQ    2.0         2.222222
# 132  _c_qAv00T9RIkYudBCy3NQ  N92Pbr2ygKDLkjmr-4BAPw    4.0         3.000000
# ..                      ...                     ...    ...              ...
# 257  ABOuNch7iuYBOjjFsxpM1A  KQrgpqBmIsBbdAn6CnfgCA    4.0         4.142857
# 258  kiWPm6uCidjGbsolfqEkvg  KQrgpqBmIsBbdAn6CnfgCA    4.0         4.416667
# 260  1gJw6DxTrf0Zmp9gDgYlrQ  KQrgpqBmIsBbdAn6CnfgCA    2.0         3.125000
# 262  m2uTGkOKcXqQJSmvsYvtMg  KQrgpqBmIsBbdAn6CnfgCA    1.0         2.454545
# 266  s-763p9_uqI8vr_0O_ToFQ  KQrgpqBmIsBbdAn6CnfgCA    5.0         4.857143
# 268  v2hPERrqGGxsfmT293q4mA  KLptkOv3OiNSTU4unZv9Sg    4.0         4.479554
# 274  X9BlWb6A3EPOMc_ANdJlhA  t_EiW3FlMnFTHyoeVU79xg    1.0         4.000000
# 276  m2uTGkOKcXqQJSmvsYvtMg  -InU2nAbC9AuS-Um2Cowgw    4.0         3.837838
# 279  9p_vj2TD8G4kYsHT48z05g  -InU2nAbC9AuS-Um2Cowgw    2.0         2.285714
# 280  v2hPERrqGGxsfmT293q4mA  -InU2nAbC9AuS-Um2Cowgw    4.0         4.757785
# 284  W40B1zLVNT8dnNZQt90mpw  KLptkOv3OiNSTU4unZv9Sg    4.0         3.973684
# 288  pSdNRbuinKON0LnZdHWTNQ  KLptkOv3OiNSTU4unZv9Sg    5.0         4.571429
# 293  v2hPERrqGGxsfmT293q4mA  -InU2nAbC9AuS-Um2Cowgw    5.0         4.757785
# 296  RLRYmD7XdbQPgXhlFI_Y7A  -InU2nAbC9AuS-Um2Cowgw    3.0         2.923077
# 301  AJ6oDR8G5eVbOLMvlZpKeQ  GI1WxFbY9tJ9-ChRrwnrzg    4.0         3.636364
# 305  vBXdvjjd_bD1-u4NUfR9lA  t_EiW3FlMnFTHyoeVU79xg    3.0         3.500000
# 331  v2hPERrqGGxsfmT293q4mA  t_EiW3FlMnFTHyoeVU79xg    4.0         4.533333
# 334  7M2P-xdlDSILMJDZVwVQ9A  -InU2nAbC9AuS-Um2Cowgw    4.0         3.500000
# 336  vBXdvjjd_bD1-u4NUfR9lA  muFJIZKZwbAfy_pEFKF_pw    5.0         4.846154
# 337  He5cTI8sBgNDKVA5yhEA8Q  -InU2nAbC9AuS-Um2Cowgw    5.0         4.200000
# 343  ABOuNch7iuYBOjjFsxpM1A  -InU2nAbC9AuS-Um2Cowgw    5.0         4.857143
# 346  pSdNRbuinKON0LnZdHWTNQ  t_EiW3FlMnFTHyoeVU79xg    2.0         2.428571
# 347  v2hPERrqGGxsfmT293q4mA  muFJIZKZwbAfy_pEFKF_pw    5.0         4.860724
# 352  m5S0MzB5x4ufSRc0JEC8cQ  -InU2nAbC9AuS-Um2Cowgw    4.0         4.142857
# 354  vCMLDTmNQJTshp0buV1JaA  KLptkOv3OiNSTU4unZv9Sg    5.0         4.774194
# 356  s-763p9_uqI8vr_0O_ToFQ  -InU2nAbC9AuS-Um2Cowgw    4.0         4.142857
# 365  wFFLWorAWh3hpxVLQP8YWw  -InU2nAbC9AuS-Um2Cowgw    4.0         4.211268
# 368  kiWPm6uCidjGbsolfqEkvg  -InU2nAbC9AuS-Um2Cowgw    5.0         4.760766
# 369  wFFLWorAWh3hpxVLQP8YWw  XJfvPt-8f-6d5Foaz_HYLQ    4.0         4.219512
# 376  8lCl40obN7k8v-wc4dAaiA  XJfvPt-8f-6d5Foaz_HYLQ    5.0         4.333333
#
# [85 rows x 4 columns]

# %%
# returns de hoogste value van 2e item van lijst met lijsten
def max_star_bid(inputlist):
    cpy = inputlist
    mx = max([sublist[-1] for sublist in cpy])
    for x in cpy:
        if x[-1] != mx:
            del cpy[cpy.index(x)]
    return cpy

# %%
# maak similarity matrix
def maak_sim_matrix():
    tlist = [[data[i]['business_id'], data[i]['categories'].split(', ')[x]] for i in range(len(data))  if data[i]['categories'] != None for x in range(len(data[i]['categories'].split(', ')))]
    catpd = pd.DataFrame(data=tlist, columns=['business_id', 'categories'])
    aye = catpd.pivot_table(index = 'business_id', columns = 'categories', aggfunc = 'size', fill_value=0)
    sim_matrix = create_similarity_matrix_categories(aye)
    return sim_matrix

# %%
def recommend(user_id=None, business_id=None, city=None, n=None):
    # similarity matrix maken
    sim_matrix = maak_sim_matrix()
    
    # maak een lijst van alle businesses waar de user is geweest
    already_been = [x['business_id'] for x in rdata if x['user_id'] == user_id]
    
    # als er een user_id wordt meegegeven maak persoonlijke aanbevelingen
    if user_id:
        # lijst met alle ratings die de user heeft gegeven
        ratinglist = [[x['business_id'], x['stars']] for x in rdata if x['user_id'] == user_id]
        
        # als de gebruiker geen reviews heeft geplaatst
        if not ratinglist:
            rand10 = random.sample([x['business_id'] for x in data], n)
            finlist = [{"business_id" : y['business_id'], "stars": y['stars'], "name": y['name'], "city" : y['city'], "address" : y['address']} for y in data for x in rand10 if y['business_id'] == x]
            return finlist
        
        # als de gebruiker wel reviews heeft geplaatst
        else:    
            # de hoogste rating
            max_list = max_star_bid(ratinglist)

            # random business met de hoogste rating
            random_business = random.choice(max_list)

            # series met alle similarities met random business
            top10 = sim_matrix[random_business[0]]

            # haal alle business_ids eruit waar de user is geweest 
            top10 = top10.drop(labels = already_been)

            # pak de top10 daarvan
            reclist = top10.nlargest(n+1).index.tolist()[1:]

            # maak de final list met dicts
            finlist = [{"business_id" : y['business_id'], "stars": y['stars'], "name": y['name'], "city" : y['city'], "address" : y['address']} for y in data for x in reclist if y['business_id'] == x]
            return finlist
    
    # als er geen user_id wordt meegegeven maar wel business_id
    elif business_id:       
        # series met alle similarities met business_id
        top10 = sim_matrix[business_id]
        
        # haal alle business_ids eruit waar de user is geweest
        top10 = top10.drop(labels = already_been)
        
        # pak de top10 daarvan
        reclist = top10.nlargest(n+1).index.tolist()[1:]
        
        # maak de final list met dicts
        finlist = [{"business_id" : y['business_id'], "stars": y['stars'], "name": y['name'], "city" : y['city'], "address" : y['address']} for y in data for x in reclist if y['business_id'] == x]
        return finlist
    
    # als er geen user_id en geen business_id wordt meegegeven pak 10 random business in stad
    else:
        rand10 = random.sample([x['business_id'] for x in data], n)
        finlist = [{"business_id" : y['business_id'], "stars": y['stars'], "name": y['name'], "city" : y['city'], "address" : y['address']} for y in data for x in rand10 if y['business_id'] == x]
        return finlist

# %%
recommend(user_id =None, business_id= '7xRbOtZUuw7DxOWrHeaanw', city = None, n=10)
# Out:
# [{'business_id': 'Q_0eGl-aElqHKukHvmLdwA',
#   'stars': 4.0,
#   'name': "Nelia's Smokehouse",
#   'city': 'Ambridge',
#   'address': '603 Duss Ave'},
#  {'business_id': 'Eu_zPTrNVAXkpdSxf7CJ2w',
#   'stars': 4.5,
#   'name': 'K & N Restaurant',
#   'city': 'Ambridge',
#   'address': '755 Merchant St'},
#  {'business_id': '729grSa1Wsn-hfv7D5uOxg',
#   'stars': 4.5,
#   'name': 'Pizza House',
#   'city': 'Ambridge',
#   'address': '1007 Merchant St'},
#  {'business_id': '2_7lYF6P2cYKnSiPhhVyPQ',
#   'stars': 3.0,
#   'name': 'Orbit Inn',
#   'city': 'Ambridge',
#   'address': '1327 Merchant St'},
#  {'business_id': '0EyRe-VkW8gYxxZ7NCQXeQ',
#   'stars': 4.5,
#   'name': "Fox's Pizza Den",
#   'city': 'Ambridge',
#   'address': '1204 Merchant St'},
#  {'business_id': 'tTDxa8OzmxUkpVifQ-cEWw',
#   'stars': 3.0,
#   'name': "Ni's Wok",
#   'city': 'Ambridge',
#   'address': '703 Merchant St'},
#  {'business_id': 'zBeUDwWx73QTZ34A1l0adQ',
#   'stars': 2.0,
#   'name': 'Vocelli Pizza',
#   'city': 'Ambridge',
#   'address': '447 Merchant St'},
#  {'business_id': '-InU2nAbC9AuS-Um2Cowgw',
#   'stars': 4.0,
#   'name': 'Maple Restaurant',
#   'city': 'Ambridge',
#   'address': '463 Maplewood Ave'},
#  {'business_id': 'GI1WxFbY9tJ9-ChRrwnrzg',
#   'stars': 4.5,
#   'name': 'The Stuffed Pepper',
#   'city': 'Ambridge',
#   'address': '1601 Duss Ave'},
#  {'business_id': 'muFJIZKZwbAfy_pEFKF_pw',
#   'stars': 4.5,
#   'name': "Frank's Pizzeria",
#   'city': 'Ambridge',
#   'address': '618 Duss Ave'}]

# %%
for x in data:
    print(x['business_id'])
# Out:
# dJ0R-XT78LUQeNHQkD-G9g
# 3gL18eXylqutlzqb6TmB0w
# Q_0eGl-aElqHKukHvmLdwA
# Eu_zPTrNVAXkpdSxf7CJ2w
# Yjf0i2J9q52dYIT8UVGT3g
# y3IVqEFHmrkgVKj2x1Ci4w
# 729grSa1Wsn-hfv7D5uOxg
# rdHO0LkiNe6s3716hPuQXQ
# iJhb_2JL1uIbIRYUl41uVg
# NHhzHVKVizOvA61AyN-dSw
# ftx72aqADrNYmOlMytdtCg
# RdEb3U0CDIXElVJe3w5n6g
# 7xRbOtZUuw7DxOWrHeaanw
# 2_7lYF6P2cYKnSiPhhVyPQ
# EZ9zSk4ld27LwgfANoF4VA
# 0EyRe-VkW8gYxxZ7NCQXeQ
# 4mpSNvmyG89Uqy2ahP4JMQ
# tTDxa8OzmxUkpVifQ-cEWw
# pcbVl6ZHDOJHsnetY0rJEQ
# N92Pbr2ygKDLkjmr-4BAPw
# gOu6hTevtDeTBNMOjo6fsw
# zBeUDwWx73QTZ34A1l0adQ
# EOmRHPvzR88a5R2j2uD0cQ
# TsusMt8MhyWaQOVL-MLnjA
# LHd0Y_0tIWWPvRqDb2b74Q
# lawYwEXAE-Sq2nf6co7aBg
# yyGzYDh0Qa2o8vUGMEjDRA
# KQrgpqBmIsBbdAn6CnfgCA
# c_3u2TfMWtt8OlRFYtVo_Q
# t_EiW3FlMnFTHyoeVU79xg
# -InU2nAbC9AuS-Um2Cowgw
# KLptkOv3OiNSTU4unZv9Sg
# GI1WxFbY9tJ9-ChRrwnrzg
# muFJIZKZwbAfy_pEFKF_pw
# XJfvPt-8f-6d5Foaz_HYLQ
# xM8dVGLkYaL94EuAIkjMEA
